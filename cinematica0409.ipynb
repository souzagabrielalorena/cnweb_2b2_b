# %% [markdown]
# <a href="https://colab.research.google.com/github/souzagabrielalorena/cnweb_2b2_b/blob/main/cinematica0409.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formula da Velocidade Média

# %%
def calcVelMedia(deltaS, deltaT):
  velMedia = (deltaS / deltaT)
  return velMedia

# %%
  print('Velocidade Média: ',calcVelMedia(50, 4))
# Out:
# Velocidade Média:  12.5

# %% [markdown]
# teste de serviço: velocidade media

# %% [markdown]
# # Fórmula da aceleração

# %%
def calcularVelMedia(Velocidade, Tempo):
  velMedia = (Velocidade / Tempo)
  return velMedia
print("Aceleração =", calcularVelMedia(18,2))
# Out:
# Aceleração = 9.0

# %% [markdown]
# # Fórmulas do Movimento Uniforme (MU)

# %% [markdown]
# ## Função horária do deslocamento

# %%
def calcularDeslocamento(velocidade, tempo):
  deslocamento = velocidade * tempo
  return deslocamento
print("Função horária ", calcularDeslocamento(18, 2))
# Out:
# Função horária  36

# %% [markdown]
# # Fórmulas do Movimento Uniformemente Variado (MUV)

# %%
def calcularVelocidadeMUV(velocidade_inicial, aceleracao, tempo):

  velocidade_final = velocidade_inicial + (aceleracao * tempo)
  return velocidade_final
print("Movimento Variado ", calcularVelocidadeMUV(16, 2,2))
# Out:
# Movimento Variado  20

# %% [markdown]
# ## Função horária da posição

# %%
def calcularPosicaoMUV(posicao_inicial, velocidade_inicial, aceleracao, tempo):
  posicao_final = posicao_inicial + (velocidade_inicial * tempo) + (0.5 * aceleracao * (tempo ** 2))
  return posicao_final
print("Função horária da posição:", calcularPosicaoMUV(15,4,3,5))
# Out:
# Função horária da posição: 72.5

# %% [markdown]
# ## Equação de Torricelli

# %%
import math

def calcTorricelli(vZero, acel, desloc):
  t = 2 * acel * desloc
  vFinal = t + vZero
  res = round(math.sqrt(vFinal), 2)
  return

# %% [markdown]
# # Fórmula do movimento vertical

# %% [markdown]
# ## Equação de Torricelli para lançamento vertical

# %% [markdown]
# ## Velocidade vertical em função do tempo

# %% [markdown]
# ## Posição vertical em função do tempo
