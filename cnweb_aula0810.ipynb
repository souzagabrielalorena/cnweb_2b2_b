# %% [markdown]
# <a href="https://colab.research.google.com/github/souzagabrielalorena/cnweb_2b2_b/blob/main/cnweb_aula0810.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # instalação das bibliotecas da nuvens

# %%
# !pip install matplotlib
# !pip install seaborn
# !pip install pandas
# !pip install numpy
# !pip install sklearn
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import pandas as pd

def converterPlanilha():
  df_tecnico = pd.read_csv("/content/drive/MyDrive/dados_icoma/Tabela_Curso_Tecnico_2025_V2.csv",
                           sep=";",
                           encoding="latin1")
  print(df_tecnico.describe())
  return(df_tecnico)

# %%
tecnico = converterPlanilha()
# Out:
#        NU_ANO_CENSO     CO_REGIAO         CO_UF  CO_MUNICIPIO  \
# count       32136.0  32136.000000  32136.000000  3.213600e+04
# mean         2025.0      2.883184     32.205439  3.238369e+06
# std             0.0      0.968003      9.049905  9.075882e+05
# min          2025.0      1.000000     11.000000  1.100023e+06
# 25%          2025.0      2.000000     26.000000  2.609600e+06
# 50%          2025.0      3.000000     33.000000  3.302007e+06
# 75%          2025.0      3.000000     35.000000  3.550308e+06
# max          2025.0      5.000000     53.000000  5.300108e+06
#
#        CO_REGIAO_GEOG_INTERM  CO_REGIAO_GEOG_IMED   CO_DISTRITO  \
# count           32136.000000         32136.000000  3.213600e+04
# mean             3224.013101        322067.008837  3.238369e+08
# std               905.295174         90500.307455  9.075882e+07
# min              1101.000000        110001.000000  1.100023e+08
# 25%              2601.000000        260001.000000  2.609600e+08
# ...
